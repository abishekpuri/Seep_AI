# %%
from random import choice
from Game import *

# %% [markdown]
# # This is the structure of the MCTS
#
# 1. We are given a board state to evaluate (GS)
#
# 2. We want to run 100 simulations from this board state till game completion, choosing weighted random moves
#
# 3. At the end of each simulation, we want to backtrack the choices and update them.
#
# 4. Once 100 simulations are done, we use the info to decide what move the player should make.

# %%
def get_opt_Move(Center,Player1,Player2):
    Player1.possibleMoves(Center)
    maxTime = 0.5/len(Player1.moves)
    scores = {}
    for move in Player1.moves:
        score = 0
        count = 0
        currTime = time.time()
        while time.time() - currTime < maxTime:
            count += 1
            score += run_game(Center,Player1,Player2,move)
        scores[Player1.printMove(move)] = (move,float(score/count))
    move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
    print("Optimal Move For",Player1.id,"With Hand Size",len(Player1.hand),"Is",Player1.printMove(move))
    Player1.doMove(move,Center)
    return move

# %%
def run_game(Center, Player1, Player2,move,debug=False):
    if debug:
        print(Center)
    center = copy.deepcopy(Center)
    p1 = copy.deepcopy(Player1)
    p2 = copy.deepcopy(Player2)
    p1.doMove(move,center)
    if debug:
        print("Player 1 Does",p1.printMove(move))
    while len(p1.hand) > 0 or len(p1.hand) > 0:
        p2move = get_opt_Move(center,p2,p1)
        if debug:
            print("Player 2 Does",p2.printMove(p2move))
        p1move = get_opt_ove(center,p1,p2)
        if debug:
            print("Player 1 Does",p2.printMove(p1move))
    if debug:
        print("p1 Score",p1.calculateScore(),"p2 score",p2.calculateScore())
    if p1.calculateScore() > p2.calculateScore():
        return 1
    else:
        return 0

# %%
def make_pile(value):
    return Pile.Pile(value, [Card.Card(0,value)])

# %%
player = Player.Player(0)
player2 = Player.Player(1)
player.hand = [Card.Card(1, 9), Card.Card(2,10)]
player2.hand = [Card.Card(0,9),Card.Card(0,11)]
center = Center.Center()
center.piles = [make_pile(9)]

# %%
player.possibleMoves(center)
maxTime = 5/len(player.moves)
print(maxTime)
scores = {}
for move in player.moves:
    score = 0
    count = 0
    currTime = time.time()
    while time.time() - currTime < maxTime:
        count += 1
        score += run_game(center,player,player2,move)
    scores[player.printMove(move)] = (move,float(score/count))
# Out:
# 2.5
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Hearts To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Throw 9 Of Spades To Center
# Optimal Move For 0 With Hand Size 1 Is Throw 9 Of Hearts To Center
# Optimal Move For 1 With Hand Size 1 Is Throw 11 Of Spades To Center
# Optimal Move For 1 With Hand Size 2 Is Use 9 Of Spades To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 1 Is Throw 9 Of Hearts To Center
# Optimal Move For 0 With Hand Size 1 Is Throw 10 Of Clubs To Center
# Optimal Move For 1 With Hand Size 1 Is Throw 11 Of Spades To Center
# Optimal Move For 0 With Hand Size 1 Is Throw 10 Of Clubs To Center
# Optimal Move For 1 With Hand Size 1 Is Throw 9 Of Spades To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 9 Of Spades To Center
# Optimal Move For 0 With Hand Size 1 Is Throw 10 Of Clubs To Center

# %%
player.printMove(scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0])
# Out:
# 'Use 9 Of Hearts To Pick Up Piles 9'

# %%
# Game Scenario

center = Center.Center()
deck = Deck.Deck()
computer = Player.Player(0)
human = Player.Player(1)

validBidHand = False
while not(validBidHand):
    deck = Deck.Deck()
    computer = Player.Player(0)
    human = Player.Player(1)
    for i in range(4):
        human.addCardsToHand([deck.dealCard()])
        computer.addCardsToHand([deck.dealCard()])
    if max([c.value for c in human.hand]) >= 9:
        validBidHand = True
for i in range(4):
    card = deck.dealCard()
    center.addNewPile(Pile.Pile(card.value,[card]),True)
for i in range(8):
    human.addCardsToHand([deck.dealCard()])
    computer.addCardsToHand([deck.dealCard()])

# %%
computer.possibleMoves(center)
maxTime = 20/len(computer.moves)
for move in computer.moves:
    score = 0
    count = 0
    currTime = time.time()
    while time.time() - currTime < maxTime:
        count += 1
        score += run_game(center,computer,human,move)
    print(computer.printMove(move),score,count)
# Out:
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 2 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 2 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 4 , 5
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 5 , 7
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 2 Is Use 9 Of Clubs To Pick Up Piles 4 , 5
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Diamonds To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 4 , 5
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 5 , 7
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 2 Is Use 9 Of Clubs To Pick Up Piles 4 , 5
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 1 With Hand Size 2 Is Use 12 Of Clubs To Pick Up Piles 12
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Diamonds To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Diamonds To Center
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Diamonds To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Diamonds To Center
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Diamonds To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Diamonds To Center
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 2 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Diamonds To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Diamonds To Center
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Diamonds To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Diamonds To Center
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Diamonds To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Diamonds To Center
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Diamonds To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Diamonds To Center
# Optimal Move For 0 With Hand Size 1 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 2 Is Use 9 Of Clubs To Pick Up Piles 9
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Diamonds To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Diamonds To Center
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Use 13 Of Hearts To Pick Up Piles 13
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# Optimal Move For 1 With Hand Size 1 Is Throw 12 Of Clubs To Center
# Optimal Move For 1 With Hand Size 2 Is Throw 12 Of Clubs To Center
# Optimal Move For 0 With Hand Size 1 Is Use 10 Of Clubs To Pick Up Piles 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-af79722fa775> in <module>()
#       7     while time.time() - currTime < maxTime:
#       8         count += 1
# ----> 9         score += run_game(center,computer,human,move)
#      10     print(computer.printMove(move),score,count)
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       9         print("Player 1 Does",p1.printMove(move))
#      10     while len(p1.hand) > 0 or len(p1.hand) > 0:
# ---> 11         p2move = get_opt_Move(center,p2,p1)
#      12         if debug:
#      13             print("Player 2 Does",p2.printMove(p2move))
#
# <ipython-input-25-62858a6c5634> in get_opt_Move(Center, Player1, Player2)
#       9         while time.time() - currTime < maxTime:
#      10             count += 1
# ---> 11             score += run_game(Center,Player1,Player2,move)
#      12         scores[Player1.printMove(move)] = (move,float(score/count))
#      13     move = scores[max(scores.keys(), key=(lambda k: scores[k][1]))][0]
#
# <ipython-input-18-c74f0e27aff3> in run_game(Center, Player1, Player2, move, debug)
#       3         print(Center)
#       4     center = copy.deepcopy(Center)
# ----> 5     p1 = copy.deepcopy(Player1)
#       6     p2 = copy.deepcopy(Player2)
#       7     p1.doMove(move,center)
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     178                     y = x
#     179                 else:
# --> 180                     y = _reconstruct(x, memo, *rv)
#     181
#     182     # If is its own copy, don't memoize.
#
# ~/anaconda3/lib/python3.6/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     278     if state is not None:
#     279         if deep:
# --> 280             state = deepcopy(state, memo)
#     281         if hasattr(y, '__setstate__'):
#     282             y.__setstate__(state)
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# ~/anaconda3/lib/python3.6/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     178                     y = x
#     179                 else:
# --> 180                     y = _reconstruct(x, memo, *rv)
#     181
#     182     # If is its own copy, don't memoize.
#
# ~/anaconda3/lib/python3.6/copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     278     if state is not None:
#     279         if deep:
# --> 280             state = deepcopy(state, memo)
#     281         if hasattr(y, '__setstate__'):
#     282             y.__setstate__(state)
#
# ~/anaconda3/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     182     # If is its own copy, don't memoize.
#     183     if y is not x:
# --> 184         memo[d] = y
#     185         _keep_alive(x, memo) # Make sure x lives at least as long as d
#     186     return y
#
# KeyboardInterrupt:
